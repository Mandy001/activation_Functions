# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    
    return stats, keys

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider

import os
os.environ["MLP_DATA_DIR"] = "..\data"

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)
# Out:
# ..\data\mnist-train.npz
# ..\data\mnist-valid.npz

# %% [markdown]
# ## Part2A
# ### different activation layers such as  SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer....

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


model_SigmoidLayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_ReluLayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_LeakyReluLayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_ELULayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_SELULayer = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])




error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('SigmoidLayer\n\n')
[stats_SigmoidLayer, keys_SigmoidLayer] = train_model_and_plot_stats(
    model_SigmoidLayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('ReluLayer\n\n')
[stats_ReluLayer, keys_ReluLayer] = train_model_and_plot_stats(
    model_ReluLayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('LeakyReluLayer\n\n')
[stats_LeakyReluLayer, keys_LeakyReluLayer] = train_model_and_plot_stats(
    model_LeakyReluLayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('ELULayer\n\n')
[stats_ELULayer, keys_ELULayer] = train_model_and_plot_stats(
    model_ELULayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('SELULayer\n\n')
[stats_SELULayer, keys_SELULayer] = train_model_and_plot_stats(
    model_SELULayer, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)


 # Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_1.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_1.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_1.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different activation layers  in the training dataset')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('Part2A_activation_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_2.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_2.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_2.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different activation layers  in the valid dataset')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('Part2A_activation_valid_error.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_3.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_3.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_3.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different activation layers  in the training dataset')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('Part2A_activation_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_SigmoidLayer.shape[0]) * stats_interval,
            stats_SigmoidLayer[1:, keys_SigmoidLayer[k]], label='SigmoidLayer')
    ax_4.plot(np.arange(1, stats_ReluLayer.shape[0]) * stats_interval,
            stats_ReluLayer[1:, keys_ReluLayer[k]], label='ReluLayer')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer.shape[0]) * stats_interval,
            stats_LeakyReluLayer[1:, keys_LeakyReluLayer[k]], label='LeakyReluLayer')

    ax_4.plot(np.arange(1, stats_ELULayer.shape[0]) * stats_interval,
            stats_ELULayer[1:, keys_ELULayer[k]], label='ELULayer')

    ax_4.plot(np.arange(1, stats_SELULayer.shape[0]) * stats_interval,
            stats_SELULayer[1:, keys_SELULayer[k]], label='SELULayer')
ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different activation layers  in the valid dataset')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('Part2A_activation_valid_acc.pdf') # Save figure to current directory in PDF format
#
# Out:
# SigmoidLayer
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 0.9s to complete
#     error(train)=1.01e+00, acc(train)=7.44e-01, error(valid)=9.79e-01, acc(valid)=7.67e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 0.9s to complete
#     error(train)=5.69e-01, acc(train)=8.44e-01, error(valid)=5.34e-01, acc(valid)=8.56e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 0.9s to complete
#     error(train)=4.30e-01, acc(train)=8.83e-01, error(valid)=4.01e-01, acc(valid)=8.92e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 0.9s to complete
#     error(train)=3.71e-01, acc(train)=8.96e-01, error(valid)=3.46e-01, acc(valid)=9.02e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 0.8s to complete
#     error(train)=3.37e-01, acc(train)=9.05e-01, error(valid)=3.14e-01, acc(valid)=9.10e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 0.9s to complete
#     error(train)=3.11e-01, acc(train)=9.12e-01, error(valid)=2.90e-01, acc(valid)=9.17e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 0.8s to complete
#     error(train)=2.93e-01, acc(train)=9.16e-01, error(valid)=2.74e-01, acc(valid)=9.23e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 0.9s to complete
#     error(train)=2.76e-01, acc(train)=9.21e-01, error(valid)=2.59e-01, acc(valid)=9.26e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 0.8s to complete
#     error(train)=2.62e-01, acc(train)=9.24e-01, error(valid)=2.47e-01, acc(valid)=9.27e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 0.9s to complete
#     error(train)=2.52e-01, acc(train)=9.27e-01, error(valid)=2.38e-01, acc(valid)=9.32e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 0.8s to complete
#     error(train)=2.41e-01, acc(train)=9.30e-01, error(valid)=2.28e-01, acc(valid)=9.35e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 0.8s to complete
#     error(train)=2.29e-01, acc(train)=9.34e-01, error(valid)=2.18e-01, acc(valid)=9.39e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 0.8s to complete
#     error(train)=2.21e-01, acc(train)=9.36e-01, error(valid)=2.12e-01, acc(valid)=9.41e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 0.8s to complete
#     error(train)=2.11e-01, acc(train)=9.39e-01, error(valid)=2.03e-01, acc(valid)=9.43e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 0.8s to complete
#     error(train)=2.02e-01, acc(train)=9.42e-01, error(valid)=1.94e-01, acc(valid)=9.46e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 0.8s to complete
#     error(train)=1.95e-01, acc(train)=9.44e-01, error(valid)=1.89e-01, acc(valid)=9.46e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 17: 0.8s to complete
#     error(train)=1.88e-01, acc(train)=9.45e-01, error(valid)=1.83e-01, acc(valid)=9.48e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 18: 0.8s to complete
#     error(train)=1.81e-01, acc(train)=9.48e-01, error(valid)=1.77e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 19: 0.8s to complete
#     error(train)=1.76e-01, acc(train)=9.49e-01, error(valid)=1.72e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 20: 0.8s to complete
#     error(train)=1.70e-01, acc(train)=9.51e-01, error(valid)=1.68e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 21: 0.8s to complete
#     error(train)=1.63e-01, acc(train)=9.53e-01, error(valid)=1.63e-01, acc(valid)=9.55e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 22: 0.8s to complete
#     error(train)=1.57e-01, acc(train)=9.55e-01, error(valid)=1.58e-01, acc(valid)=9.56e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 23: 0.8s to complete
#     error(train)=1.53e-01, acc(train)=9.56e-01, error(valid)=1.55e-01, acc(valid)=9.57e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 24: 0.8s to complete
#     error(train)=1.47e-01, acc(train)=9.58e-01, error(valid)=1.50e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 25: 0.8s to complete
#     error(train)=1.43e-01, acc(train)=9.58e-01, error(valid)=1.48e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 26: 0.8s to complete
#     error(train)=1.40e-01, acc(train)=9.60e-01, error(valid)=1.46e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 27: 0.8s to complete
#     error(train)=1.34e-01, acc(train)=9.62e-01, error(valid)=1.40e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 28: 0.8s to complete
#     error(train)=1.30e-01, acc(train)=9.63e-01, error(valid)=1.38e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 0.8s to complete
#     error(train)=1.26e-01, acc(train)=9.64e-01, error(valid)=1.35e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 0.8s to complete
#     error(train)=1.24e-01, acc(train)=9.64e-01, error(valid)=1.33e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 0.8s to complete
#     error(train)=1.20e-01, acc(train)=9.65e-01, error(valid)=1.31e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 0.8s to complete
#     error(train)=1.16e-01, acc(train)=9.67e-01, error(valid)=1.28e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 0.8s to complete
#     error(train)=1.13e-01, acc(train)=9.68e-01, error(valid)=1.26e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 0.8s to complete
#     error(train)=1.10e-01, acc(train)=9.68e-01, error(valid)=1.25e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 0.8s to complete
#     error(train)=1.07e-01, acc(train)=9.69e-01, error(valid)=1.23e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 0.8s to complete
#     error(train)=1.07e-01, acc(train)=9.69e-01, error(valid)=1.23e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 0.8s to complete
#     error(train)=1.03e-01, acc(train)=9.71e-01, error(valid)=1.20e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 0.8s to complete
#     error(train)=9.94e-02, acc(train)=9.73e-01, error(valid)=1.17e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 0.8s to complete
#     error(train)=9.64e-02, acc(train)=9.73e-01, error(valid)=1.16e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 0.8s to complete
#     error(train)=9.50e-02, acc(train)=9.73e-01, error(valid)=1.15e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 0.8s to complete
#     error(train)=9.19e-02, acc(train)=9.75e-01, error(valid)=1.13e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 0.9s to complete
#     error(train)=9.03e-02, acc(train)=9.75e-01, error(valid)=1.12e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 0.8s to complete
#     error(train)=8.81e-02, acc(train)=9.76e-01, error(valid)=1.12e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 0.8s to complete
#     error(train)=8.70e-02, acc(train)=9.76e-01, error(valid)=1.10e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 0.9s to complete
#     error(train)=8.40e-02, acc(train)=9.77e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 0.9s to complete
#     error(train)=8.18e-02, acc(train)=9.78e-01, error(valid)=1.07e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 0.8s to complete
#     error(train)=7.99e-02, acc(train)=9.79e-01, error(valid)=1.06e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 0.9s to complete
#     error(train)=7.83e-02, acc(train)=9.79e-01, error(valid)=1.05e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 0.9s to complete
#     error(train)=7.74e-02, acc(train)=9.79e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 0.9s to complete
#     error(train)=7.49e-02, acc(train)=9.80e-01, error(valid)=1.03e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 0.9s to complete
#     error(train)=7.35e-02, acc(train)=9.80e-01, error(valid)=1.02e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 0.9s to complete
#     error(train)=7.17e-02, acc(train)=9.81e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 0.9s to complete
#     error(train)=7.01e-02, acc(train)=9.81e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 0.9s to complete
#     error(train)=6.87e-02, acc(train)=9.81e-01, error(valid)=9.96e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 0.9s to complete
#     error(train)=6.79e-02, acc(train)=9.82e-01, error(valid)=9.95e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 0.9s to complete
#     error(train)=6.68e-02, acc(train)=9.82e-01, error(valid)=1.00e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 0.8s to complete
#     error(train)=6.44e-02, acc(train)=9.83e-01, error(valid)=9.94e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 0.9s to complete
#     error(train)=6.35e-02, acc(train)=9.83e-01, error(valid)=9.85e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 0.9s to complete
#     error(train)=6.15e-02, acc(train)=9.84e-01, error(valid)=9.63e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 0.9s to complete
#     error(train)=6.02e-02, acc(train)=9.84e-01, error(valid)=9.58e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 0.9s to complete
#     error(train)=5.94e-02, acc(train)=9.84e-01, error(valid)=9.63e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 0.9s to complete
#     error(train)=5.80e-02, acc(train)=9.85e-01, error(valid)=9.56e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 0.9s to complete
#     error(train)=5.65e-02, acc(train)=9.85e-01, error(valid)=9.40e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 0.8s to complete
#     error(train)=5.55e-02, acc(train)=9.85e-01, error(valid)=9.44e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 0.8s to complete
#     error(train)=5.42e-02, acc(train)=9.86e-01, error(valid)=9.33e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 0.8s to complete
#     error(train)=5.41e-02, acc(train)=9.86e-01, error(valid)=9.31e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 0.8s to complete
#     error(train)=5.24e-02, acc(train)=9.87e-01, error(valid)=9.15e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 0.8s to complete
#     error(train)=5.14e-02, acc(train)=9.87e-01, error(valid)=9.32e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 0.8s to complete
#     error(train)=5.09e-02, acc(train)=9.87e-01, error(valid)=9.24e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 0.8s to complete
#     error(train)=4.95e-02, acc(train)=9.87e-01, error(valid)=9.22e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 0.8s to complete
#     error(train)=4.85e-02, acc(train)=9.88e-01, error(valid)=9.27e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 0.8s to complete
#     error(train)=4.71e-02, acc(train)=9.88e-01, error(valid)=9.06e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 0.8s to complete
#     error(train)=4.64e-02, acc(train)=9.88e-01, error(valid)=9.09e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 0.8s to complete
#     error(train)=4.62e-02, acc(train)=9.88e-01, error(valid)=9.03e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 0.8s to complete
#     error(train)=4.46e-02, acc(train)=9.89e-01, error(valid)=9.04e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 0.8s to complete
#     error(train)=4.42e-02, acc(train)=9.89e-01, error(valid)=9.02e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 0.8s to complete
#     error(train)=4.38e-02, acc(train)=9.89e-01, error(valid)=8.90e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 0.8s to complete
#     error(train)=4.14e-02, acc(train)=9.90e-01, error(valid)=8.80e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 0.8s to complete
#     error(train)=4.09e-02, acc(train)=9.90e-01, error(valid)=8.79e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 0.9s to complete
#     error(train)=4.17e-02, acc(train)=9.90e-01, error(valid)=8.89e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 0.9s to complete
#     error(train)=3.93e-02, acc(train)=9.91e-01, error(valid)=8.77e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 0.8s to complete
#     error(train)=3.86e-02, acc(train)=9.91e-01, error(valid)=8.73e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 0.9s to complete
#     error(train)=3.82e-02, acc(train)=9.91e-01, error(valid)=8.87e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 0.8s to complete
#     error(train)=3.74e-02, acc(train)=9.92e-01, error(valid)=8.66e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 0.8s to complete
#     error(train)=3.68e-02, acc(train)=9.92e-01, error(valid)=8.71e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 0.8s to complete
#     error(train)=3.56e-02, acc(train)=9.92e-01, error(valid)=8.64e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 0.8s to complete
#     error(train)=3.49e-02, acc(train)=9.92e-01, error(valid)=8.59e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 0.8s to complete
#     error(train)=3.42e-02, acc(train)=9.92e-01, error(valid)=8.57e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 0.8s to complete
#     error(train)=3.31e-02, acc(train)=9.93e-01, error(valid)=8.53e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 0.8s to complete
#     error(train)=3.34e-02, acc(train)=9.93e-01, error(valid)=8.60e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 0.8s to complete
#     error(train)=3.19e-02, acc(train)=9.93e-01, error(valid)=8.57e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 0.8s to complete
#     error(train)=3.17e-02, acc(train)=9.93e-01, error(valid)=8.54e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 0.8s to complete
#     error(train)=3.09e-02, acc(train)=9.94e-01, error(valid)=8.55e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 0.8s to complete
#     error(train)=3.02e-02, acc(train)=9.94e-01, error(valid)=8.60e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 0.8s to complete
#     error(train)=2.97e-02, acc(train)=9.94e-01, error(valid)=8.42e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 0.8s to complete
#     error(train)=2.93e-02, acc(train)=9.94e-01, error(valid)=8.49e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 0.8s to complete
#     error(train)=2.89e-02, acc(train)=9.94e-01, error(valid)=8.56e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 0.8s to complete
#     error(train)=2.82e-02, acc(train)=9.94e-01, error(valid)=8.60e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 0.8s to complete
#     error(train)=2.75e-02, acc(train)=9.95e-01, error(valid)=8.36e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 0.8s to complete
#     error(train)=2.75e-02, acc(train)=9.95e-01, error(valid)=8.54e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# ReluLayer
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 0.7s to complete
#     error(train)=2.49e-01, acc(train)=9.26e-01, error(valid)=2.35e-01, acc(valid)=9.32e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 0.7s to complete
#     error(train)=1.68e-01, acc(train)=9.51e-01, error(valid)=1.68e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 0.7s to complete
#     error(train)=1.35e-01, acc(train)=9.60e-01, error(valid)=1.42e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 0.7s to complete
#     error(train)=1.01e-01, acc(train)=9.71e-01, error(valid)=1.17e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 0.7s to complete
#     error(train)=8.92e-02, acc(train)=9.73e-01, error(valid)=1.09e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 0.7s to complete
#     error(train)=7.61e-02, acc(train)=9.78e-01, error(valid)=9.99e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 0.7s to complete
#     error(train)=6.86e-02, acc(train)=9.80e-01, error(valid)=9.89e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 0.7s to complete
#     error(train)=5.96e-02, acc(train)=9.83e-01, error(valid)=9.19e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 0.7s to complete
#     error(train)=5.29e-02, acc(train)=9.85e-01, error(valid)=9.29e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 0.7s to complete
#     error(train)=4.53e-02, acc(train)=9.87e-01, error(valid)=8.76e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 0.7s to complete
#     error(train)=4.41e-02, acc(train)=9.87e-01, error(valid)=8.86e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 0.7s to complete
#     error(train)=3.24e-02, acc(train)=9.92e-01, error(valid)=8.13e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 0.8s to complete
#     error(train)=3.69e-02, acc(train)=9.89e-01, error(valid)=8.90e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 0.7s to complete
#     error(train)=2.66e-02, acc(train)=9.94e-01, error(valid)=8.16e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 0.7s to complete
#     error(train)=2.37e-02, acc(train)=9.94e-01, error(valid)=8.05e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 0.7s to complete
#     error(train)=2.30e-02, acc(train)=9.94e-01, error(valid)=8.32e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 17: 0.7s to complete
#     error(train)=1.93e-02, acc(train)=9.96e-01, error(valid)=8.20e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 18: 0.7s to complete
#     error(train)=2.19e-02, acc(train)=9.94e-01, error(valid)=9.17e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 19: 0.7s to complete
#     error(train)=1.49e-02, acc(train)=9.97e-01, error(valid)=8.12e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 20: 0.7s to complete
#     error(train)=1.28e-02, acc(train)=9.98e-01, error(valid)=8.19e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 21: 0.7s to complete
#     error(train)=1.40e-02, acc(train)=9.97e-01, error(valid)=8.60e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 22: 0.7s to complete
#     error(train)=1.13e-02, acc(train)=9.98e-01, error(valid)=8.09e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 23: 0.7s to complete
#     error(train)=8.79e-03, acc(train)=9.99e-01, error(valid)=8.41e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 24: 0.7s to complete
#     error(train)=8.55e-03, acc(train)=9.99e-01, error(valid)=8.44e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 25: 0.7s to complete
#     error(train)=7.88e-03, acc(train)=9.99e-01, error(valid)=8.46e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 26: 0.7s to complete
#     error(train)=7.17e-03, acc(train)=9.99e-01, error(valid)=8.52e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 27: 0.7s to complete
#     error(train)=6.06e-03, acc(train)=9.99e-01, error(valid)=8.64e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 28: 0.7s to complete
#     error(train)=5.98e-03, acc(train)=1.00e+00, error(valid)=8.86e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 0.7s to complete
#     error(train)=5.08e-03, acc(train)=1.00e+00, error(valid)=8.63e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 0.7s to complete
#     error(train)=4.27e-03, acc(train)=1.00e+00, error(valid)=8.68e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 0.7s to complete
#     error(train)=3.86e-03, acc(train)=1.00e+00, error(valid)=8.54e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 0.7s to complete
#     error(train)=3.70e-03, acc(train)=1.00e+00, error(valid)=8.84e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 0.7s to complete
#     error(train)=3.43e-03, acc(train)=1.00e+00, error(valid)=8.74e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 0.7s to complete
#     error(train)=3.41e-03, acc(train)=1.00e+00, error(valid)=8.95e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 0.7s to complete
#     error(train)=3.07e-03, acc(train)=1.00e+00, error(valid)=9.24e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 0.7s to complete
#     error(train)=2.73e-03, acc(train)=1.00e+00, error(valid)=9.10e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 0.7s to complete
#     error(train)=2.64e-03, acc(train)=1.00e+00, error(valid)=9.37e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 0.8s to complete
#     error(train)=3.90e-03, acc(train)=1.00e+00, error(valid)=9.54e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 0.8s to complete
#     error(train)=2.26e-03, acc(train)=1.00e+00, error(valid)=9.30e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 0.7s to complete
#     error(train)=2.17e-03, acc(train)=1.00e+00, error(valid)=9.43e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 0.7s to complete
#     error(train)=1.92e-03, acc(train)=1.00e+00, error(valid)=9.33e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 0.7s to complete
#     error(train)=1.84e-03, acc(train)=1.00e+00, error(valid)=9.41e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 0.7s to complete
#     error(train)=1.75e-03, acc(train)=1.00e+00, error(valid)=9.45e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 0.7s to complete
#     error(train)=1.72e-03, acc(train)=1.00e+00, error(valid)=9.64e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 0.7s to complete
#     error(train)=1.70e-03, acc(train)=1.00e+00, error(valid)=9.63e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 0.7s to complete
#     error(train)=1.55e-03, acc(train)=1.00e+00, error(valid)=9.74e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 0.7s to complete
#     error(train)=1.50e-03, acc(train)=1.00e+00, error(valid)=9.82e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 0.7s to complete
#     error(train)=1.40e-03, acc(train)=1.00e+00, error(valid)=9.69e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 0.8s to complete
#     error(train)=1.33e-03, acc(train)=1.00e+00, error(valid)=9.76e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 0.8s to complete
#     error(train)=1.29e-03, acc(train)=1.00e+00, error(valid)=9.77e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 0.7s to complete
#     error(train)=1.24e-03, acc(train)=1.00e+00, error(valid)=9.92e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 0.7s to complete
#     error(train)=1.20e-03, acc(train)=1.00e+00, error(valid)=9.92e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 0.8s to complete
#     error(train)=1.13e-03, acc(train)=1.00e+00, error(valid)=9.88e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 0.8s to complete
#     error(train)=1.10e-03, acc(train)=1.00e+00, error(valid)=9.95e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 0.7s to complete
#     error(train)=1.06e-03, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 0.7s to complete
#     error(train)=1.04e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 0.7s to complete
#     error(train)=1.01e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 0.7s to complete
#     error(train)=9.81e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 0.7s to complete
#     error(train)=9.51e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 0.7s to complete
#     error(train)=9.21e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 0.7s to complete
#     error(train)=8.97e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 0.7s to complete
#     error(train)=8.62e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 0.7s to complete
#     error(train)=8.55e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 0.7s to complete
#     error(train)=8.19e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 0.7s to complete
#     error(train)=8.04e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 0.7s to complete
#     error(train)=7.98e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 0.7s to complete
#     error(train)=7.51e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 0.7s to complete
#     error(train)=7.43e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 0.7s to complete
#     error(train)=7.28e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 0.7s to complete
#     error(train)=7.16e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 0.7s to complete
#     error(train)=6.89e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 0.7s to complete
#     error(train)=6.83e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 0.7s to complete
#     error(train)=6.67e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 0.7s to complete
#     error(train)=6.44e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 0.7s to complete
#     error(train)=6.29e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 0.7s to complete
#     error(train)=6.18e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 0.7s to complete
#     error(train)=6.06e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 0.7s to complete
#     error(train)=5.88e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 0.7s to complete
#     error(train)=5.76e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 0.7s to complete
#     error(train)=5.83e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 0.7s to complete
#     error(train)=5.63e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 0.7s to complete
#     error(train)=5.49e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 0.7s to complete
#     error(train)=5.39e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 0.7s to complete
#     error(train)=5.24e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 0.7s to complete
#     error(train)=5.14e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 0.7s to complete
#     error(train)=5.09e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 0.7s to complete
#     error(train)=5.03e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 0.7s to complete
#     error(train)=4.89e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 0.7s to complete
#     error(train)=4.81e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 0.7s to complete
#     error(train)=4.71e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 0.7s to complete
#     error(train)=4.64e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 0.7s to complete
#     error(train)=4.56e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 0.7s to complete
#     error(train)=4.51e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 0.7s to complete
#     error(train)=4.39e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 0.7s to complete
#     error(train)=4.34e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 0.7s to complete
#     error(train)=4.27e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 0.7s to complete
#     error(train)=4.18e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 0.7s to complete
#     error(train)=4.15e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 0.7s to complete
#     error(train)=4.08e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 0.7s to complete
#     error(train)=4.02e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# LeakyReluLayer
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 0.8s to complete
#     error(train)=2.41e-01, acc(train)=9.29e-01, error(valid)=2.27e-01, acc(valid)=9.33e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 0.8s to complete
#     error(train)=1.82e-01, acc(train)=9.45e-01, error(valid)=1.79e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 0.8s to complete
#     error(train)=1.28e-01, acc(train)=9.62e-01, error(valid)=1.36e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 0.8s to complete
#     error(train)=1.26e-01, acc(train)=9.63e-01, error(valid)=1.39e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 0.8s to complete
#     error(train)=9.17e-02, acc(train)=9.74e-01, error(valid)=1.13e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 0.8s to complete
#     error(train)=8.95e-02, acc(train)=9.73e-01, error(valid)=1.15e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 0.8s to complete
#     error(train)=7.38e-02, acc(train)=9.78e-01, error(valid)=1.08e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 0.8s to complete
#     error(train)=5.90e-02, acc(train)=9.83e-01, error(valid)=9.48e-02, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 0.8s to complete
#     error(train)=5.04e-02, acc(train)=9.86e-01, error(valid)=9.14e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 0.8s to complete
#     error(train)=4.57e-02, acc(train)=9.88e-01, error(valid)=9.02e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 0.8s to complete
#     error(train)=4.43e-02, acc(train)=9.87e-01, error(valid)=9.34e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 0.8s to complete
#     error(train)=3.43e-02, acc(train)=9.91e-01, error(valid)=8.52e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 0.8s to complete
#     error(train)=3.47e-02, acc(train)=9.91e-01, error(valid)=8.78e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 0.8s to complete
#     error(train)=3.01e-02, acc(train)=9.92e-01, error(valid)=8.72e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 0.8s to complete
#     error(train)=2.53e-02, acc(train)=9.94e-01, error(valid)=8.11e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 0.8s to complete
#     error(train)=2.14e-02, acc(train)=9.95e-01, error(valid)=7.98e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# ...
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 1.0s to complete
#     error(train)=1.08e-02, acc(train)=9.98e-01, error(valid)=8.74e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 1.0s to complete
#     error(train)=9.10e-03, acc(train)=9.99e-01, error(valid)=8.58e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 1.0s to complete
#     error(train)=8.14e-03, acc(train)=9.99e-01, error(valid)=8.66e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 1.0s to complete
#     error(train)=7.70e-03, acc(train)=9.99e-01, error(valid)=8.74e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 1.0s to complete
#     error(train)=7.92e-03, acc(train)=9.99e-01, error(valid)=8.91e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 1.0s to complete
#     error(train)=6.23e-03, acc(train)=9.99e-01, error(valid)=8.91e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 1.0s to complete
#     error(train)=5.90e-03, acc(train)=1.00e+00, error(valid)=8.92e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 1.0s to complete
#     error(train)=5.08e-03, acc(train)=1.00e+00, error(valid)=8.78e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 1.0s to complete
#     error(train)=4.79e-03, acc(train)=1.00e+00, error(valid)=9.01e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 1.0s to complete
#     error(train)=4.94e-03, acc(train)=1.00e+00, error(valid)=8.93e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 1.0s to complete
#     error(train)=4.49e-03, acc(train)=1.00e+00, error(valid)=9.09e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 1.0s to complete
#     error(train)=3.62e-03, acc(train)=1.00e+00, error(valid)=8.94e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 1.0s to complete
#     error(train)=3.49e-03, acc(train)=1.00e+00, error(valid)=9.27e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 1.0s to complete
#     error(train)=3.35e-03, acc(train)=1.00e+00, error(valid)=9.32e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 1.0s to complete
#     error(train)=2.94e-03, acc(train)=1.00e+00, error(valid)=9.17e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 1.1s to complete
#     error(train)=2.93e-03, acc(train)=1.00e+00, error(valid)=9.32e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 1.1s to complete
#     error(train)=2.69e-03, acc(train)=1.00e+00, error(valid)=9.37e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 1.1s to complete
#     error(train)=2.60e-03, acc(train)=1.00e+00, error(valid)=9.40e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 1.1s to complete
#     error(train)=2.52e-03, acc(train)=1.00e+00, error(valid)=9.29e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 1.1s to complete
#     error(train)=2.39e-03, acc(train)=1.00e+00, error(valid)=9.55e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 1.1s to complete
#     error(train)=2.11e-03, acc(train)=1.00e+00, error(valid)=9.54e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 1.1s to complete
#     error(train)=2.13e-03, acc(train)=1.00e+00, error(valid)=9.68e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 1.1s to complete
#     error(train)=2.20e-03, acc(train)=1.00e+00, error(valid)=9.77e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 1.1s to complete
#     error(train)=1.88e-03, acc(train)=1.00e+00, error(valid)=9.64e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 1.1s to complete
#     error(train)=1.80e-03, acc(train)=1.00e+00, error(valid)=9.55e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 1.1s to complete
#     error(train)=1.84e-03, acc(train)=1.00e+00, error(valid)=9.84e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 1.1s to complete
#     error(train)=1.66e-03, acc(train)=1.00e+00, error(valid)=9.87e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 1.1s to complete
#     error(train)=1.69e-03, acc(train)=1.00e+00, error(valid)=9.87e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 1.1s to complete
#     error(train)=1.56e-03, acc(train)=1.00e+00, error(valid)=9.84e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 1.0s to complete
#     error(train)=1.49e-03, acc(train)=1.00e+00, error(valid)=9.87e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 1.0s to complete
#     error(train)=1.44e-03, acc(train)=1.00e+00, error(valid)=9.91e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 1.0s to complete
#     error(train)=1.42e-03, acc(train)=1.00e+00, error(valid)=9.87e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 1.0s to complete
#     error(train)=1.40e-03, acc(train)=1.00e+00, error(valid)=9.94e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 1.0s to complete
#     error(train)=1.31e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 1.0s to complete
#     error(train)=1.28e-03, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 1.0s to complete
#     error(train)=1.27e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 1.0s to complete
#     error(train)=1.26e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 1.1s to complete
#     error(train)=1.20e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 1.0s to complete
#     error(train)=1.14e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 1.0s to complete
#     error(train)=1.12e-03, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 1.0s to complete
#     error(train)=1.11e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 1.0s to complete
#     error(train)=1.03e-03, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 1.0s to complete
#     error(train)=1.01e-03, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 1.0s to complete
#     error(train)=9.99e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 1.0s to complete
#     error(train)=9.69e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 1.0s to complete
#     error(train)=9.68e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 1.0s to complete
#     error(train)=9.21e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 1.0s to complete
#     error(train)=9.01e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 1.0s to complete
#     error(train)=8.81e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 1.0s to complete
#     error(train)=8.57e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 1.0s to complete
#     error(train)=8.45e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 1.0s to complete
#     error(train)=8.16e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 1.0s to complete
#     error(train)=8.00e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 1.0s to complete
#     error(train)=7.88e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 1.1s to complete
#     error(train)=7.80e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 1.0s to complete
#     error(train)=7.54e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 1.0s to complete
#     error(train)=7.44e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 1.0s to complete
#     error(train)=7.31e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 1.0s to complete
#     error(train)=7.32e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 1.0s to complete
#     error(train)=6.93e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 1.0s to complete
#     error(train)=6.97e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 1.0s to complete
#     error(train)=6.69e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 1.0s to complete
#     error(train)=6.64e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 1.0s to complete
#     error(train)=6.40e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 1.0s to complete
#     error(train)=6.42e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 1.0s to complete
#     error(train)=6.20e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 1.0s to complete
#     error(train)=6.16e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 1.0s to complete
#     error(train)=5.98e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 1.0s to complete
#     error(train)=5.97e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 1.0s to complete
#     error(train)=5.80e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 1.0s to complete
#     error(train)=5.73e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 1.0s to complete
#     error(train)=5.62e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00

# %% [markdown]
# ## Part2B
# ### Leaky ReLU compare networks with 2–8 hidden layers, using 100 hidden units per hidden layer.

# %%
# ### Part2B
# Leaky ReLU compare networks with 2–8 hidden layers, using 100 hidden units per hidden layer.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)



model_LeakyReluLayer2 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])


model_LeakyReluLayer3 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_LeakyReluLayer4 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_LeakyReluLayer5 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_LeakyReluLayer6 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_LeakyReluLayer7 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

model_LeakyReluLayer8 = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])






error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('LeakyReluLayer 2\n\n')
[stats_LeakyReluLayer2, keys_LeakyReluLayer2] = train_model_and_plot_stats(
    model_LeakyReluLayer2, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)


print('LeakyReluLayer 3\n\n')
[stats_LeakyReluLayer3, keys_LeakyReluLayer3] = train_model_and_plot_stats(
    model_LeakyReluLayer3, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('LeakyReluLayer 4\n\n')
[stats_LeakyReluLayer4, keys_LeakyReluLayer4] = train_model_and_plot_stats(
    model_LeakyReluLayer4, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('LeakyReluLayer 5\n\n')
[stats_LeakyReluLayer5, keys_LeakyReluLayer5] = train_model_and_plot_stats(
    model_LeakyReluLayer5, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('LeakyReluLayer 6\n\n')
[stats_LeakyReluLayer6, keys_LeakyReluLayer6] = train_model_and_plot_stats(
    model_LeakyReluLayer6, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('LeakyReluLayer 7\n\n')
[stats_LeakyReluLayer7, keys_LeakyReluLayer7] = train_model_and_plot_stats(
    model_LeakyReluLayer7, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

print('LeakyReluLayer 8\n\n')
[stats_LeakyReluLayer8, keys_LeakyReluLayer8] = train_model_and_plot_stats(
    model_LeakyReluLayer8, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)



 # Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_LeakyReluLayer2.shape[0]) * stats_interval,
            stats_LeakyReluLayer2[1:, keys_LeakyReluLayer2[k]], label='2 layers')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer3.shape[0]) * stats_interval,
            stats_LeakyReluLayer3[1:, keys_LeakyReluLayer3[k]], label='3 layers')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer4.shape[0]) * stats_interval,
            stats_LeakyReluLayer4[1:, keys_LeakyReluLayer4[k]], label='4 layers')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer5.shape[0]) * stats_interval,
            stats_LeakyReluLayer5[1:, keys_LeakyReluLayer5[k]], label='5 layers')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer6.shape[0]) * stats_interval,
            stats_LeakyReluLayer6[1:, keys_LeakyReluLayer6[k]], label='6 layers')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer7.shape[0]) * stats_interval,
            stats_LeakyReluLayer7[1:, keys_LeakyReluLayer7[k]], label='7 layers')

    ax_1.plot(np.arange(1, stats_LeakyReluLayer8.shape[0]) * stats_interval,
            stats_LeakyReluLayer8[1:, keys_LeakyReluLayer8[k]], label='8 layers')

ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different layers in the training dataset')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('Part2B_layers_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_LeakyReluLayer2.shape[0]) * stats_interval,
            stats_LeakyReluLayer2[1:, keys_LeakyReluLayer2[k]], label='2 layers')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer3.shape[0]) * stats_interval,
            stats_LeakyReluLayer3[1:, keys_LeakyReluLayer3[k]], label='3 layers')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer4.shape[0]) * stats_interval,
            stats_LeakyReluLayer4[1:, keys_LeakyReluLayer4[k]], label='4 layers')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer5.shape[0]) * stats_interval,
            stats_LeakyReluLayer5[1:, keys_LeakyReluLayer5[k]], label='5 layers')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer6.shape[0]) * stats_interval,
            stats_LeakyReluLayer6[1:, keys_LeakyReluLayer6[k]], label='6 layers')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer7.shape[0]) * stats_interval,
            stats_LeakyReluLayer7[1:, keys_LeakyReluLayer7[k]], label='7 layers')

    ax_2.plot(np.arange(1, stats_LeakyReluLayer8.shape[0]) * stats_interval,
            stats_LeakyReluLayer8[1:, keys_LeakyReluLayer8[k]], label='8 layers')

ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different layers  in the valid dataset')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('Part2B_layers_valid_error.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_LeakyReluLayer2.shape[0]) * stats_interval,
            stats_LeakyReluLayer2[1:, keys_LeakyReluLayer2[k]], label='2 layers')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer3.shape[0]) * stats_interval,
            stats_LeakyReluLayer3[1:, keys_LeakyReluLayer3[k]], label='3 layers')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer4.shape[0]) * stats_interval,
            stats_LeakyReluLayer4[1:, keys_LeakyReluLayer4[k]], label='4 layers')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer5.shape[0]) * stats_interval,
            stats_LeakyReluLayer5[1:, keys_LeakyReluLayer5[k]], label='5 layers')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer6.shape[0]) * stats_interval,
            stats_LeakyReluLayer6[1:, keys_LeakyReluLayer6[k]], label='6 layers')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer7.shape[0]) * stats_interval,
            stats_LeakyReluLayer7[1:, keys_LeakyReluLayer7[k]], label='7 layers')

    ax_3.plot(np.arange(1, stats_LeakyReluLayer8.shape[0]) * stats_interval,
            stats_LeakyReluLayer8[1:, keys_LeakyReluLayer8[k]], label='8 layers')

ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different layers  in the training dataset')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('Part2B_layers_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_LeakyReluLayer2.shape[0]) * stats_interval,
            stats_LeakyReluLayer2[1:, keys_LeakyReluLayer2[k]], label='2 layers')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer3.shape[0]) * stats_interval,
            stats_LeakyReluLayer3[1:, keys_LeakyReluLayer3[k]], label='3 layers')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer4.shape[0]) * stats_interval,
            stats_LeakyReluLayer4[1:, keys_LeakyReluLayer4[k]], label='4 layers')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer5.shape[0]) * stats_interval,
            stats_LeakyReluLayer5[1:, keys_LeakyReluLayer5[k]], label='5 layers')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer6.shape[0]) * stats_interval,
            stats_LeakyReluLayer6[1:, keys_LeakyReluLayer6[k]], label='6 layers')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer7.shape[0]) * stats_interval,
            stats_LeakyReluLayer7[1:, keys_LeakyReluLayer7[k]], label='7 layers')

    ax_4.plot(np.arange(1, stats_LeakyReluLayer8.shape[0]) * stats_interval,
            stats_LeakyReluLayer8[1:, keys_LeakyReluLayer8[k]], label='8 layers')

ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different layers in the valid dataset')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('Part2B_layers_valid_acc.pdf') # Save figure to current directory in PDF format
#
# Out:
# LeakyReluLayer 2
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 0.8s to complete
#     error(train)=2.53e-01, acc(train)=9.25e-01, error(valid)=2.40e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 0.8s to complete
#     error(train)=1.75e-01, acc(train)=9.48e-01, error(valid)=1.73e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 0.8s to complete
#     error(train)=1.31e-01, acc(train)=9.62e-01, error(valid)=1.40e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 0.8s to complete
#     error(train)=1.18e-01, acc(train)=9.65e-01, error(valid)=1.40e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 0.8s to complete
#     error(train)=9.01e-02, acc(train)=9.74e-01, error(valid)=1.15e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 0.8s to complete
#     error(train)=7.99e-02, acc(train)=9.76e-01, error(valid)=1.07e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 0.8s to complete
#     error(train)=6.45e-02, acc(train)=9.82e-01, error(valid)=9.74e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 0.8s to complete
#     error(train)=5.70e-02, acc(train)=9.84e-01, error(valid)=9.41e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 0.8s to complete
#     error(train)=5.01e-02, acc(train)=9.86e-01, error(valid)=8.98e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 0.8s to complete
#     error(train)=4.83e-02, acc(train)=9.87e-01, error(valid)=9.23e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 0.8s to complete
#     error(train)=4.61e-02, acc(train)=9.87e-01, error(valid)=9.54e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 0.8s to complete
#     error(train)=3.58e-02, acc(train)=9.91e-01, error(valid)=8.82e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 0.8s to complete
#     error(train)=3.55e-02, acc(train)=9.90e-01, error(valid)=9.03e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 0.8s to complete
#     error(train)=2.86e-02, acc(train)=9.93e-01, error(valid)=8.74e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 0.8s to complete
#     error(train)=2.51e-02, acc(train)=9.94e-01, error(valid)=8.64e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 0.8s to complete
#     error(train)=2.39e-02, acc(train)=9.94e-01, error(valid)=8.92e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 17: 0.8s to complete
#     error(train)=2.19e-02, acc(train)=9.95e-01, error(valid)=8.88e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 18: 0.8s to complete
#     error(train)=1.72e-02, acc(train)=9.97e-01, error(valid)=8.42e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 19: 0.8s to complete
#     error(train)=1.71e-02, acc(train)=9.96e-01, error(valid)=9.17e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 20: 0.8s to complete
#     error(train)=1.55e-02, acc(train)=9.97e-01, error(valid)=8.97e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 21: 0.8s to complete
#     error(train)=1.48e-02, acc(train)=9.97e-01, error(valid)=9.22e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 22: 0.8s to complete
#     error(train)=1.22e-02, acc(train)=9.98e-01, error(valid)=9.00e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 23: 0.8s to complete
#     error(train)=1.33e-02, acc(train)=9.97e-01, error(valid)=9.37e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 24: 0.8s to complete
#     error(train)=8.25e-03, acc(train)=9.99e-01, error(valid)=8.81e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 25: 0.8s to complete
#     error(train)=7.75e-03, acc(train)=9.99e-01, error(valid)=9.06e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 26: 0.8s to complete
#     error(train)=6.89e-03, acc(train)=9.99e-01, error(valid)=9.17e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 27: 0.8s to complete
#     error(train)=6.12e-03, acc(train)=1.00e+00, error(valid)=9.23e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 28: 0.8s to complete
#     error(train)=6.54e-03, acc(train)=9.99e-01, error(valid)=9.55e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 0.8s to complete
#     error(train)=5.06e-03, acc(train)=1.00e+00, error(valid)=9.29e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 0.8s to complete
#     error(train)=5.13e-03, acc(train)=1.00e+00, error(valid)=9.67e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 0.8s to complete
#     error(train)=4.30e-03, acc(train)=1.00e+00, error(valid)=9.60e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 0.8s to complete
#     error(train)=3.83e-03, acc(train)=1.00e+00, error(valid)=9.63e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 0.8s to complete
#     error(train)=3.56e-03, acc(train)=1.00e+00, error(valid)=9.77e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 0.8s to complete
#     error(train)=3.61e-03, acc(train)=1.00e+00, error(valid)=9.68e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 0.8s to complete
#     error(train)=2.90e-03, acc(train)=1.00e+00, error(valid)=9.81e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 0.8s to complete
#     error(train)=2.99e-03, acc(train)=1.00e+00, error(valid)=9.80e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 0.8s to complete
#     error(train)=2.51e-03, acc(train)=1.00e+00, error(valid)=9.86e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 0.8s to complete
#     error(train)=2.95e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 0.8s to complete
#     error(train)=2.19e-03, acc(train)=1.00e+00, error(valid)=9.92e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 0.8s to complete
#     error(train)=2.31e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 0.8s to complete
#     error(train)=2.04e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 0.8s to complete
#     error(train)=1.89e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 0.8s to complete
#     error(train)=1.81e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 0.8s to complete
#     error(train)=1.72e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 0.8s to complete
#     error(train)=1.64e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 0.8s to complete
#     error(train)=1.60e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 0.8s to complete
#     error(train)=1.59e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 0.8s to complete
#     error(train)=1.42e-03, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 0.8s to complete
#     error(train)=1.41e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 0.8s to complete
#     error(train)=1.30e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 0.8s to complete
#     error(train)=1.27e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 0.8s to complete
#     error(train)=1.21e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 0.8s to complete
#     error(train)=1.34e-03, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 0.8s to complete
#     error(train)=1.14e-03, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 0.8s to complete
#     error(train)=1.13e-03, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 0.8s to complete
#     error(train)=1.05e-03, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 0.8s to complete
#     error(train)=1.04e-03, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 0.8s to complete
#     error(train)=9.91e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 0.8s to complete
#     error(train)=9.65e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 0.8s to complete
#     error(train)=9.17e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 0.8s to complete
#     error(train)=9.00e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 0.8s to complete
#     error(train)=8.77e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 0.8s to complete
#     error(train)=8.47e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 0.8s to complete
#     error(train)=8.47e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 0.8s to complete
#     error(train)=8.00e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 0.8s to complete
#     error(train)=8.05e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 0.8s to complete
#     error(train)=7.74e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 0.8s to complete
#     error(train)=7.56e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 0.8s to complete
#     error(train)=7.50e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 0.8s to complete
#     error(train)=7.06e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 0.8s to complete
#     error(train)=6.96e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 0.8s to complete
#     error(train)=6.88e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 0.8s to complete
#     error(train)=6.69e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 0.8s to complete
#     error(train)=6.65e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 0.8s to complete
#     error(train)=6.47e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 0.8s to complete
#     error(train)=6.17e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 0.8s to complete
#     error(train)=6.07e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 0.8s to complete
#     error(train)=6.05e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 0.8s to complete
#     error(train)=5.97e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 0.8s to complete
#     error(train)=5.76e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 0.8s to complete
#     error(train)=5.68e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 0.8s to complete
#     error(train)=5.55e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 0.8s to complete
#     error(train)=5.42e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 0.8s to complete
#     error(train)=5.34e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 0.8s to complete
#     error(train)=5.23e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 0.8s to complete
#     error(train)=5.29e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 0.8s to complete
#     error(train)=5.03e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 0.8s to complete
#     error(train)=4.93e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 0.8s to complete
#     error(train)=4.86e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 0.8s to complete
#     error(train)=4.77e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 0.8s to complete
#     error(train)=4.73e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 0.8s to complete
#     error(train)=4.58e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 0.8s to complete
#     error(train)=4.54e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 0.8s to complete
#     error(train)=4.41e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 0.8s to complete
#     error(train)=4.39e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 0.8s to complete
#     error(train)=4.29e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 0.8s to complete
#     error(train)=4.25e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 0.8s to complete
#     error(train)=4.22e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 0.8s to complete
#     error(train)=4.10e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 0.8s to complete
#     error(train)=4.08e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# LeakyReluLayer 3
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 1.0s to complete
#     error(train)=2.16e-01, acc(train)=9.36e-01, error(valid)=2.02e-01, acc(valid)=9.42e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 1.0s to complete
#     error(train)=1.58e-01, acc(train)=9.51e-01, error(valid)=1.58e-01, acc(valid)=9.55e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 1.0s to complete
#     error(train)=1.12e-01, acc(train)=9.67e-01, error(valid)=1.27e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 1.0s to complete
#     error(train)=8.70e-02, acc(train)=9.75e-01, error(valid)=1.08e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 1.0s to complete
#     error(train)=6.89e-02, acc(train)=9.80e-01, error(valid)=9.93e-02, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 1.0s to complete
#     error(train)=6.38e-02, acc(train)=9.82e-01, error(valid)=9.84e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 1.0s to complete
#     error(train)=5.04e-02, acc(train)=9.85e-01, error(valid)=9.18e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 1.0s to complete
#     error(train)=4.17e-02, acc(train)=9.88e-01, error(valid)=8.82e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 1.0s to complete
#     error(train)=3.47e-02, acc(train)=9.91e-01, error(valid)=8.43e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 1.0s to complete
#     error(train)=4.09e-02, acc(train)=9.87e-01, error(valid)=9.76e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 1.0s to complete
#     error(train)=6.14e-02, acc(train)=9.79e-01, error(valid)=1.22e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 1.0s to complete
#     error(train)=2.60e-02, acc(train)=9.93e-01, error(valid)=9.17e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 1.0s to complete
#     error(train)=2.65e-02, acc(train)=9.92e-01, error(valid)=9.34e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 1.0s to complete
#     error(train)=1.57e-02, acc(train)=9.96e-01, error(valid)=8.32e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 1.0s to complete
#     error(train)=1.56e-02, acc(train)=9.96e-01, error(valid)=8.54e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 1.0s to complete
#     error(train)=1.29e-02, acc(train)=9.97e-01, error(valid)=8.80e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 17: 1.0s to complete
#     error(train)=1.14e-02, acc(train)=9.97e-01, error(valid)=9.16e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 18: 1.0s to complete
#     error(train)=1.19e-02, acc(train)=9.97e-01, error(valid)=9.66e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 19: 1.0s to complete
#     error(train)=5.80e-03, acc(train)=9.99e-01, error(valid)=9.07e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 20: 1.0s to complete
#     error(train)=5.57e-03, acc(train)=9.99e-01, error(valid)=9.37e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 21: 1.0s to complete
#     error(train)=4.61e-03, acc(train)=9.99e-01, error(valid)=9.56e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 22: 1.0s to complete
#     error(train)=3.60e-03, acc(train)=1.00e+00, error(valid)=9.34e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 23: 1.0s to complete
#     error(train)=2.65e-03, acc(train)=1.00e+00, error(valid)=9.56e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 24: 1.0s to complete
#     error(train)=2.67e-03, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 25: 1.0s to complete
#     error(train)=2.42e-03, acc(train)=1.00e+00, error(valid)=9.84e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 26: 1.0s to complete
#     error(train)=1.60e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 27: 1.0s to complete
#     error(train)=1.30e-03, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 28: 1.0s to complete
#     error(train)=1.27e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 1.0s to complete
#     error(train)=1.06e-03, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 0.9s to complete
#     error(train)=1.00e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 1.0s to complete
#     error(train)=9.19e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 1.0s to complete
#     error(train)=8.37e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 1.0s to complete
#     error(train)=7.90e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 1.0s to complete
#     error(train)=7.50e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 1.0s to complete
#     error(train)=6.95e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 1.0s to complete
#     error(train)=6.62e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 1.0s to complete
#     error(train)=6.15e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 1.0s to complete
#     error(train)=6.26e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 1.0s to complete
#     error(train)=5.62e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 1.0s to complete
#     error(train)=5.29e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 1.0s to complete
#     error(train)=5.07e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 1.0s to complete
#     error(train)=4.76e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 1.0s to complete
#     error(train)=4.71e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 1.0s to complete
#     error(train)=4.49e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 1.0s to complete
#     error(train)=4.31e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 1.0s to complete
#     error(train)=4.03e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 1.0s to complete
#     error(train)=3.90e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 1.0s to complete
#     error(train)=3.84e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 1.0s to complete
#     error(train)=3.61e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 1.0s to complete
#     error(train)=3.57e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 1.0s to complete
#     error(train)=3.44e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 1.0s to complete
#     error(train)=3.32e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 1.0s to complete
#     error(train)=3.20e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 1.0s to complete
#     error(train)=3.16e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 1.0s to complete
#     error(train)=2.98e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 1.0s to complete
#     error(train)=2.93e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 1.0s to complete
#     error(train)=2.90e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 1.0s to complete
#     error(train)=2.75e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 1.0s to complete
#     error(train)=2.71e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 1.0s to complete
#     error(train)=2.61e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 1.0s to complete
#     error(train)=2.54e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 1.1s to complete
#     error(train)=2.46e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 1.1s to complete
#     error(train)=2.40e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 1.0s to complete
#     error(train)=2.34e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 1.0s to complete
#     error(train)=2.28e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 1.0s to complete
#     error(train)=2.25e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 1.0s to complete
#     error(train)=2.19e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 1.0s to complete
#     error(train)=2.16e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 1.0s to complete
#     error(train)=2.08e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 1.0s to complete
#     error(train)=2.07e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 1.0s to complete
#     error(train)=2.00e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 1.0s to complete
#     error(train)=1.95e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 1.0s to complete
#     error(train)=1.92e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 1.0s to complete
#     error(train)=1.87e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 1.0s to complete
#     error(train)=1.84e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 1.0s to complete
#     error(train)=1.82e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 1.0s to complete
#     error(train)=1.78e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 1.0s to complete
#     error(train)=1.74e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 1.0s to complete
#     error(train)=1.73e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 1.0s to complete
#     error(train)=1.66e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 1.0s to complete
#     error(train)=1.66e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 1.0s to complete
#     error(train)=1.61e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 1.0s to complete
#     error(train)=1.58e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 1.0s to complete
#     error(train)=1.56e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 1.0s to complete
#     error(train)=1.53e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 1.0s to complete
#     error(train)=1.50e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 1.0s to complete
#     error(train)=1.48e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 1.0s to complete
#     error(train)=1.46e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 1.0s to complete
#     error(train)=1.44e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 1.0s to complete
#     error(train)=1.40e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 1.0s to complete
#     error(train)=1.38e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 1.0s to complete
#     error(train)=1.36e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 1.0s to complete
#     error(train)=1.35e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 1.0s to complete
#     error(train)=1.32e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 0.9s to complete
#     error(train)=1.30e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 1.0s to complete
#     error(train)=1.28e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 1.0s to complete
#     error(train)=1.26e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 1.0s to complete
#     error(train)=1.24e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 1.0s to complete
#     error(train)=1.23e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 1.0s to complete
#     error(train)=1.21e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# LeakyReluLayer 4
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 1.1s to complete
#     error(train)=2.13e-01, acc(train)=9.36e-01, error(valid)=2.04e-01, acc(valid)=9.39e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 1.2s to complete
#     error(train)=1.44e-01, acc(train)=9.56e-01, error(valid)=1.48e-01, acc(valid)=9.57e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 1.1s to complete
#     error(train)=9.77e-02, acc(train)=9.70e-01, error(valid)=1.13e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 1.2s to complete
#     error(train)=7.55e-02, acc(train)=9.77e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 1.2s to complete
#     error(train)=6.01e-02, acc(train)=9.83e-01, error(valid)=9.39e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 1.2s to complete
#     error(train)=6.42e-02, acc(train)=9.80e-01, error(valid)=1.06e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 1.2s to complete
#     error(train)=4.86e-02, acc(train)=9.85e-01, error(valid)=1.02e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 1.2s to complete
#     error(train)=4.09e-02, acc(train)=9.88e-01, error(valid)=9.56e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 1.2s to complete
#     error(train)=3.43e-02, acc(train)=9.89e-01, error(valid)=8.96e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 1.3s to complete
#     error(train)=2.47e-02, acc(train)=9.93e-01, error(valid)=9.07e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 1.3s to complete
#     error(train)=2.22e-02, acc(train)=9.94e-01, error(valid)=8.97e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 1.2s to complete
#     error(train)=1.63e-02, acc(train)=9.96e-01, error(valid)=9.29e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 1.2s to complete
#     error(train)=1.67e-02, acc(train)=9.95e-01, error(valid)=1.01e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 1.2s to complete
#     error(train)=1.52e-02, acc(train)=9.96e-01, error(valid)=9.10e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 1.2s to complete
#     error(train)=8.92e-03, acc(train)=9.98e-01, error(valid)=9.52e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 1.2s to complete
#     error(train)=1.96e-02, acc(train)=9.93e-01, error(valid)=1.21e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 1.9s to complete
#     error(train)=2.20e-03, acc(train)=9.99e-01, error(valid)=1.17e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 1.9s to complete
#     error(train)=2.17e-03, acc(train)=9.99e-01, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 1.9s to complete
#     error(train)=3.71e-03, acc(train)=9.99e-01, error(valid)=1.32e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 1.9s to complete
#     error(train)=4.40e-03, acc(train)=9.99e-01, error(valid)=1.38e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 1.9s to complete
#     error(train)=2.30e-03, acc(train)=9.99e-01, error(valid)=1.35e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 2.0s to complete
#     error(train)=2.51e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 1.9s to complete
#     error(train)=1.56e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 1.9s to complete
#     error(train)=1.19e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 1.9s to complete
#     error(train)=9.37e-05, acc(train)=1.00e+00, error(valid)=1.41e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 1.9s to complete
#     error(train)=7.69e-05, acc(train)=1.00e+00, error(valid)=1.44e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 1.9s to complete
#     error(train)=6.54e-05, acc(train)=1.00e+00, error(valid)=1.46e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 1.9s to complete
#     error(train)=5.72e-05, acc(train)=1.00e+00, error(valid)=1.47e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 1.9s to complete
#     error(train)=5.06e-05, acc(train)=1.00e+00, error(valid)=1.49e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 1.9s to complete
#     error(train)=4.53e-05, acc(train)=1.00e+00, error(valid)=1.51e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 1.9s to complete
#     error(train)=4.10e-05, acc(train)=1.00e+00, error(valid)=1.52e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 1.9s to complete
#     error(train)=3.72e-05, acc(train)=1.00e+00, error(valid)=1.54e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 1.9s to complete
#     error(train)=3.42e-05, acc(train)=1.00e+00, error(valid)=1.55e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 1.9s to complete
#     error(train)=3.16e-05, acc(train)=1.00e+00, error(valid)=1.56e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 1.9s to complete
#     error(train)=2.93e-05, acc(train)=1.00e+00, error(valid)=1.57e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 1.9s to complete
#     error(train)=2.73e-05, acc(train)=1.00e+00, error(valid)=1.58e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 1.9s to complete
#     error(train)=2.56e-05, acc(train)=1.00e+00, error(valid)=1.59e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 1.9s to complete
#     error(train)=2.41e-05, acc(train)=1.00e+00, error(valid)=1.60e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 1.9s to complete
#     error(train)=2.27e-05, acc(train)=1.00e+00, error(valid)=1.61e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 1.9s to complete
#     error(train)=2.15e-05, acc(train)=1.00e+00, error(valid)=1.62e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 1.9s to complete
#     error(train)=2.04e-05, acc(train)=1.00e+00, error(valid)=1.63e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 1.9s to complete
#     error(train)=1.94e-05, acc(train)=1.00e+00, error(valid)=1.63e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 1.9s to complete
#     error(train)=1.85e-05, acc(train)=1.00e+00, error(valid)=1.64e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 1.9s to complete
#     error(train)=1.77e-05, acc(train)=1.00e+00, error(valid)=1.65e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 1.9s to complete
#     error(train)=1.69e-05, acc(train)=1.00e+00, error(valid)=1.66e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 1.9s to complete
#     error(train)=1.62e-05, acc(train)=1.00e+00, error(valid)=1.66e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 1.9s to complete
#     error(train)=1.56e-05, acc(train)=1.00e+00, error(valid)=1.67e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 1.9s to complete
#     error(train)=1.50e-05, acc(train)=1.00e+00, error(valid)=1.67e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 1.9s to complete
#     error(train)=1.44e-05, acc(train)=1.00e+00, error(valid)=1.68e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 1.9s to complete
#     error(train)=1.39e-05, acc(train)=1.00e+00, error(valid)=1.69e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 1.9s to complete
#     error(train)=1.34e-05, acc(train)=1.00e+00, error(valid)=1.69e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 1.9s to complete
#     error(train)=1.30e-05, acc(train)=1.00e+00, error(valid)=1.70e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 1.9s to complete
#     error(train)=1.25e-05, acc(train)=1.00e+00, error(valid)=1.70e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 1.9s to complete
#     error(train)=1.21e-05, acc(train)=1.00e+00, error(valid)=1.71e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 1.9s to complete
#     error(train)=1.17e-05, acc(train)=1.00e+00, error(valid)=1.71e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 1.9s to complete
#     error(train)=1.14e-05, acc(train)=1.00e+00, error(valid)=1.72e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 1.9s to complete
#     error(train)=1.10e-05, acc(train)=1.00e+00, error(valid)=1.72e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 1.9s to complete
#     error(train)=1.07e-05, acc(train)=1.00e+00, error(valid)=1.73e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 1.9s to complete
#     error(train)=1.04e-05, acc(train)=1.00e+00, error(valid)=1.73e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 1.9s to complete
#     error(train)=1.01e-05, acc(train)=1.00e+00, error(valid)=1.74e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 1.9s to complete
#     error(train)=9.86e-06, acc(train)=1.00e+00, error(valid)=1.74e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 1.9s to complete
#     error(train)=9.60e-06, acc(train)=1.00e+00, error(valid)=1.75e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 2.0s to complete
#     error(train)=9.35e-06, acc(train)=1.00e+00, error(valid)=1.75e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 1.9s to complete
#     error(train)=9.12e-06, acc(train)=1.00e+00, error(valid)=1.75e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 1.9s to complete
#     error(train)=8.89e-06, acc(train)=1.00e+00, error(valid)=1.76e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 1.9s to complete
#     error(train)=8.68e-06, acc(train)=1.00e+00, error(valid)=1.76e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 1.9s to complete
#     error(train)=8.48e-06, acc(train)=1.00e+00, error(valid)=1.77e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 1.9s to complete
#     error(train)=8.28e-06, acc(train)=1.00e+00, error(valid)=1.77e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 1.9s to complete
#     error(train)=8.10e-06, acc(train)=1.00e+00, error(valid)=1.77e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 1.9s to complete
#     error(train)=7.92e-06, acc(train)=1.00e+00, error(valid)=1.78e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 1.9s to complete
#     error(train)=7.75e-06, acc(train)=1.00e+00, error(valid)=1.78e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 1.9s to complete
#     error(train)=7.59e-06, acc(train)=1.00e+00, error(valid)=1.78e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 1.9s to complete
#     error(train)=7.43e-06, acc(train)=1.00e+00, error(valid)=1.79e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 1.9s to complete
#     error(train)=7.28e-06, acc(train)=1.00e+00, error(valid)=1.79e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 1.9s to complete
#     error(train)=7.13e-06, acc(train)=1.00e+00, error(valid)=1.79e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 1.9s to complete
#     error(train)=6.99e-06, acc(train)=1.00e+00, error(valid)=1.80e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 1.9s to complete
#     error(train)=6.86e-06, acc(train)=1.00e+00, error(valid)=1.80e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 1.9s to complete
#     error(train)=6.73e-06, acc(train)=1.00e+00, error(valid)=1.80e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 1.9s to complete
#     error(train)=6.60e-06, acc(train)=1.00e+00, error(valid)=1.81e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 2.0s to complete
#     error(train)=6.48e-06, acc(train)=1.00e+00, error(valid)=1.81e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 1.9s to complete
#     error(train)=6.36e-06, acc(train)=1.00e+00, error(valid)=1.81e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 1.9s to complete
#     error(train)=6.25e-06, acc(train)=1.00e+00, error(valid)=1.81e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 1.9s to complete
#     error(train)=6.14e-06, acc(train)=1.00e+00, error(valid)=1.82e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 1.9s to complete
#     error(train)=6.03e-06, acc(train)=1.00e+00, error(valid)=1.82e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 1.9s to complete
#     error(train)=5.93e-06, acc(train)=1.00e+00, error(valid)=1.82e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 1.9s to complete
#     error(train)=5.83e-06, acc(train)=1.00e+00, error(valid)=1.83e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 1.9s to complete
#     error(train)=5.73e-06, acc(train)=1.00e+00, error(valid)=1.83e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 1.9s to complete
#     error(train)=5.64e-06, acc(train)=1.00e+00, error(valid)=1.83e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00

# %% [markdown]
# ## Part2B
# ### Part2B, we will use different weight initialisations to train network.

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit,GlorotUniformInitFanIn,GlorotUniformInitFanOut,GlorotNormalInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_initFan_inFan_out = GlorotUniformInit(rng=rng)
weights_initFan_in = GlorotUniformInitFanIn(rng=rng)
weights_initFan_out = GlorotUniformInitFanOut(rng=rng)
weights_initNormal = GlorotNormalInit(rng=rng)
weights_initSELU = SELUInit(rng=rng)

biases_init = ConstantInit(0.)
model_LeakyReluLayerFan_inFan_out = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_initFan_inFan_out, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_initFan_inFan_out, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_initFan_inFan_out, biases_init)
])


model_LeakyReluLayerFan_in = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_initFan_in, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_initFan_in, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_initFan_in, biases_init)
])

model_LeakyReluLayerFan_out = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_initFan_out, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_initFan_out, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_initFan_out, biases_init)
])

model_LeakyReluLayerNormal = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_initNormal, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_initNormal, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_initNormal, biases_init)
])

model_LeakyReluLayerSELU = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_initSELU, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_initSELU, biases_init),
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_initSELU, biases_init)
])


error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
print('LeakyReluLayer 2\n\n')
[stats_LeakyReluLayerFan_inFan_out, keys_LeakyReluLayerFan_inFan_out] = train_model_and_plot_stats(
    model_LeakyReluLayerFan_inFan_out, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

[stats_LeakyReluLayerFan_in, keys_LeakyReluLayerFan_in] = train_model_and_plot_stats(
    model_LeakyReluLayerFan_in, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

[stats_LeakyReluLayerFan_out, keys_LeakyReluLayerFan_out] = train_model_and_plot_stats(
    model_LeakyReluLayerFan_out, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

[stats_LeakyReluLayerNormal, keys_LeakyReluLayerNormal] = train_model_and_plot_stats(
    model_LeakyReluLayerNormal, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

[stats_LeakyReluLayerSELU, keys_LeakyReluLayerSELU] = train_model_and_plot_stats(
    model_LeakyReluLayerSELU, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)




 # Plot the change in the validation and training set error over training.
# Plot Errors of different activation layers  in the training dataset
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)']:
    ax_1.plot(np.arange(1, stats_LeakyReluLayerFan_inFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_inFan_out[1:, keys_LeakyReluLayerFan_inFan_out[k]], label='Fan_inFan_out')

    ax_1.plot(np.arange(1, stats_LeakyReluLayerFan_in.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_in[1:, keys_LeakyReluLayerFan_in[k]], label='Fan_in')

    ax_1.plot(np.arange(1, stats_LeakyReluLayerFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_out[1:, keys_LeakyReluLayerFan_out[k]], label='Fan_out')

    ax_1.plot(np.arange(1, stats_LeakyReluLayerNormal.shape[0]) * stats_interval,
            stats_LeakyReluLayerNormal[1:, keys_LeakyReluLayerNormal[k]], label='Normal')

    ax_1.plot(np.arange(1, stats_LeakyReluLayerSELU.shape[0]) * stats_interval,
            stats_LeakyReluLayerSELU[1:, keys_LeakyReluLayerSELU[k]], label='SELU')



ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')
ax_1.set_ylabel('Error(train)')

ax_1.set_title('Errors of different initialisations in the training dataset')
fig_1.tight_layout() # This minimises whitespace around the axes.
fig_1.savefig('Part2B_initial_train_error.pdf') # Save figure to current directory in PDF format
#

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['error(valid)']:
    ax_2.plot(np.arange(1, stats_LeakyReluLayerFan_inFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_inFan_out[1:, keys_LeakyReluLayerFan_inFan_out[k]], label='Fan_inFan_out')

    ax_2.plot(np.arange(1, stats_LeakyReluLayerFan_in.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_in[1:, keys_LeakyReluLayerFan_in[k]], label='Fan_in')

    ax_2.plot(np.arange(1, stats_LeakyReluLayerFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_out[1:, keys_LeakyReluLayerFan_out[k]], label='Fan_out')

    ax_2.plot(np.arange(1, stats_LeakyReluLayerNormal.shape[0]) * stats_interval,
            stats_LeakyReluLayerNormal[1:, keys_LeakyReluLayerNormal[k]], label='Normal')

    ax_2.plot(np.arange(1, stats_LeakyReluLayerSELU.shape[0]) * stats_interval,
            stats_LeakyReluLayerSELU[1:, keys_LeakyReluLayerSELU[k]], label='SELU')

ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
ax_2.set_ylabel('Error(valid)')

ax_2.set_title('Errors of different initialisations  in the valid dataset')
fig_2.tight_layout() # This minimises whitespace around the axes.
fig_2.savefig('Part2B_initial_valid_error.pdf') # Save figure to current directory in PDF format
#


fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in ['acc(train)']:
    ax_3.plot(np.arange(1, stats_LeakyReluLayerFan_inFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_inFan_out[1:, keys_LeakyReluLayerFan_inFan_out[k]], label='Fan_inFan_out')

    ax_3.plot(np.arange(1, stats_LeakyReluLayerFan_in.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_in[1:, keys_LeakyReluLayerFan_in[k]], label='Fan_in')

    ax_3.plot(np.arange(1, stats_LeakyReluLayerFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_out[1:, keys_LeakyReluLayerFan_out[k]], label='Fan_out')

    ax_3.plot(np.arange(1, stats_LeakyReluLayerNormal.shape[0]) * stats_interval,
            stats_LeakyReluLayerNormal[1:, keys_LeakyReluLayerNormal[k]], label='Normal')

    ax_3.plot(np.arange(1, stats_LeakyReluLayerSELU.shape[0]) * stats_interval,
            stats_LeakyReluLayerSELU[1:, keys_LeakyReluLayerSELU[k]], label='SELU')

ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number')
ax_3.set_ylabel('Accuracy(train)')

ax_3.set_title('Accuracies of different initialisations  in the training dataset')
fig_3.tight_layout() # This minimises whitespace around the axes.
fig_3.savefig('Part2B_initial_train_acc.pdf') # Save figure to current directory in PDF format
#

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in ['acc(valid)']:
    ax_4.plot(np.arange(1, stats_LeakyReluLayerFan_inFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_inFan_out[1:, keys_LeakyReluLayerFan_inFan_out[k]], label='Fan_inFan_out')

    ax_4.plot(np.arange(1, stats_LeakyReluLayerFan_in.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_in[1:, keys_LeakyReluLayerFan_in[k]], label='Fan_in')

    ax_4.plot(np.arange(1, stats_LeakyReluLayerFan_out.shape[0]) * stats_interval,
            stats_LeakyReluLayerFan_out[1:, keys_LeakyReluLayerFan_out[k]], label='Fan_out')

    ax_4.plot(np.arange(1, stats_LeakyReluLayerNormal.shape[0]) * stats_interval,
            stats_LeakyReluLayerNormal[1:, keys_LeakyReluLayerNormal[k]], label='Normal')

    ax_4.plot(np.arange(1, stats_LeakyReluLayerSELU.shape[0]) * stats_interval,
            stats_LeakyReluLayerSELU[1:, keys_LeakyReluLayerSELU[k]], label='SELU')

ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.set_ylabel('Accuracy(valid)')

ax_4.set_title('Accuracies of different initialisations in the valid dataset')
fig_4.tight_layout() # This minimises whitespace around the axes.
fig_4.savefig('Part2B_initial_valid_acc.pdf') # Save figure to current directory in PDF format
#
# Out:
# 100:GlorotUniformInitFanIn
# 100:GlorotUniformInitFanIn
# 10:GlorotUniformInitFanIn
# 100:GlorotUniformInitFanOut
# 100:GlorotUniformInitFanOut
# 10:GlorotUniformInitFanOut
# LeakyReluLayer 2
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 0.8s to complete
#     error(train)=2.55e-01, acc(train)=9.27e-01, error(valid)=2.33e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 0.8s to complete
#     error(train)=1.72e-01, acc(train)=9.51e-01, error(valid)=1.64e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 0.8s to complete
#     error(train)=1.41e-01, acc(train)=9.58e-01, error(valid)=1.43e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 0.8s to complete
#     error(train)=1.08e-01, acc(train)=9.69e-01, error(valid)=1.21e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 0.8s to complete
#     error(train)=8.71e-02, acc(train)=9.75e-01, error(valid)=1.07e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 0.8s to complete
#     error(train)=7.72e-02, acc(train)=9.78e-01, error(valid)=1.00e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 0.8s to complete
#     error(train)=7.00e-02, acc(train)=9.80e-01, error(valid)=1.01e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 0.8s to complete
#     error(train)=5.98e-02, acc(train)=9.82e-01, error(valid)=9.22e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 0.8s to complete
#     error(train)=4.82e-02, acc(train)=9.87e-01, error(valid)=8.43e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 0.8s to complete
#     error(train)=4.38e-02, acc(train)=9.88e-01, error(valid)=8.27e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 0.8s to complete
#     error(train)=3.97e-02, acc(train)=9.89e-01, error(valid)=8.54e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 0.8s to complete
#     error(train)=4.25e-02, acc(train)=9.88e-01, error(valid)=9.52e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 0.8s to complete
#     error(train)=3.17e-02, acc(train)=9.92e-01, error(valid)=8.26e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 0.8s to complete
#     error(train)=2.85e-02, acc(train)=9.93e-01, error(valid)=8.17e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 0.8s to complete
#     error(train)=2.29e-02, acc(train)=9.95e-01, error(valid)=7.85e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 0.8s to complete
#     error(train)=2.23e-02, acc(train)=9.95e-01, error(valid)=7.93e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 17: 0.8s to complete
#     error(train)=1.98e-02, acc(train)=9.96e-01, error(valid)=7.99e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 18: 0.8s to complete
#     error(train)=2.06e-02, acc(train)=9.95e-01, error(valid)=8.54e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 19: 0.8s to complete
#     error(train)=1.52e-02, acc(train)=9.97e-01, error(valid)=8.11e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 20: 0.8s to complete
#     error(train)=1.43e-02, acc(train)=9.97e-01, error(valid)=8.19e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 21: 0.8s to complete
#     error(train)=1.33e-02, acc(train)=9.97e-01, error(valid)=8.18e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 22: 0.8s to complete
#     error(train)=1.11e-02, acc(train)=9.98e-01, error(valid)=8.14e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 23: 0.8s to complete
#     error(train)=1.05e-02, acc(train)=9.98e-01, error(valid)=8.19e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 24: 0.8s to complete
#     error(train)=8.66e-03, acc(train)=9.99e-01, error(valid)=8.07e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 25: 0.8s to complete
#     error(train)=8.97e-03, acc(train)=9.99e-01, error(valid)=8.29e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 26: 0.8s to complete
#     error(train)=6.75e-03, acc(train)=9.99e-01, error(valid)=8.01e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 27: 0.8s to complete
#     error(train)=6.58e-03, acc(train)=9.99e-01, error(valid)=8.29e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 28: 0.8s to complete
#     error(train)=6.31e-03, acc(train)=9.99e-01, error(valid)=8.59e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 0.8s to complete
#     error(train)=4.98e-03, acc(train)=1.00e+00, error(valid)=8.35e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 0.8s to complete
#     error(train)=4.77e-03, acc(train)=1.00e+00, error(valid)=8.60e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 0.8s to complete
#     error(train)=4.31e-03, acc(train)=1.00e+00, error(valid)=8.77e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 0.8s to complete
#     error(train)=3.92e-03, acc(train)=1.00e+00, error(valid)=8.69e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 0.8s to complete
#     error(train)=4.24e-03, acc(train)=1.00e+00, error(valid)=8.98e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 0.8s to complete
#     error(train)=3.34e-03, acc(train)=1.00e+00, error(valid)=8.83e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 0.8s to complete
#     error(train)=2.98e-03, acc(train)=1.00e+00, error(valid)=8.73e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 0.9s to complete
#     error(train)=3.01e-03, acc(train)=1.00e+00, error(valid)=8.75e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 0.8s to complete
#     error(train)=3.04e-03, acc(train)=1.00e+00, error(valid)=8.98e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 0.8s to complete
#     error(train)=2.37e-03, acc(train)=1.00e+00, error(valid)=8.87e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 0.8s to complete
#     error(train)=2.28e-03, acc(train)=1.00e+00, error(valid)=8.90e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 0.8s to complete
#     error(train)=2.17e-03, acc(train)=1.00e+00, error(valid)=9.02e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 0.8s to complete
#     error(train)=2.02e-03, acc(train)=1.00e+00, error(valid)=9.08e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 0.8s to complete
#     error(train)=1.96e-03, acc(train)=1.00e+00, error(valid)=9.13e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 0.8s to complete
#     error(train)=1.85e-03, acc(train)=1.00e+00, error(valid)=9.23e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 0.8s to complete
#     error(train)=1.73e-03, acc(train)=1.00e+00, error(valid)=9.18e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 0.8s to complete
#     error(train)=1.64e-03, acc(train)=1.00e+00, error(valid)=9.32e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 0.8s to complete
#     error(train)=1.81e-03, acc(train)=1.00e+00, error(valid)=9.29e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 0.8s to complete
#     error(train)=1.52e-03, acc(train)=1.00e+00, error(valid)=9.19e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 0.8s to complete
#     error(train)=1.42e-03, acc(train)=1.00e+00, error(valid)=9.35e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 0.8s to complete
#     error(train)=1.39e-03, acc(train)=1.00e+00, error(valid)=9.45e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 0.8s to complete
#     error(train)=1.34e-03, acc(train)=1.00e+00, error(valid)=9.52e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 0.8s to complete
#     error(train)=1.33e-03, acc(train)=1.00e+00, error(valid)=9.50e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 0.8s to complete
#     error(train)=1.30e-03, acc(train)=1.00e+00, error(valid)=9.55e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 0.8s to complete
#     error(train)=1.19e-03, acc(train)=1.00e+00, error(valid)=9.57e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 0.8s to complete
#     error(train)=1.38e-03, acc(train)=1.00e+00, error(valid)=9.63e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 0.8s to complete
#     error(train)=1.12e-03, acc(train)=1.00e+00, error(valid)=9.70e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 0.8s to complete
#     error(train)=1.08e-03, acc(train)=1.00e+00, error(valid)=9.75e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 0.8s to complete
#     error(train)=1.09e-03, acc(train)=1.00e+00, error(valid)=9.78e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 0.8s to complete
#     error(train)=1.00e-03, acc(train)=1.00e+00, error(valid)=9.78e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 0.8s to complete
#     error(train)=9.80e-04, acc(train)=1.00e+00, error(valid)=9.78e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 0.8s to complete
#     error(train)=9.97e-04, acc(train)=1.00e+00, error(valid)=9.86e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 0.8s to complete
#     error(train)=9.49e-04, acc(train)=1.00e+00, error(valid)=9.83e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 0.9s to complete
#     error(train)=9.01e-04, acc(train)=1.00e+00, error(valid)=9.88e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 0.8s to complete
#     error(train)=8.77e-04, acc(train)=1.00e+00, error(valid)=9.86e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 0.8s to complete
#     error(train)=8.42e-04, acc(train)=1.00e+00, error(valid)=9.93e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 0.8s to complete
#     error(train)=8.17e-04, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 0.8s to complete
#     error(train)=8.07e-04, acc(train)=1.00e+00, error(valid)=9.98e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 0.8s to complete
#     error(train)=8.06e-04, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 0.8s to complete
#     error(train)=7.72e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 0.8s to complete
#     error(train)=7.62e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 0.8s to complete
#     error(train)=7.32e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 0.8s to complete
#     error(train)=7.02e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 0.8s to complete
#     error(train)=6.99e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 0.8s to complete
#     error(train)=6.82e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 0.8s to complete
#     error(train)=6.59e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 0.8s to complete
#     error(train)=6.50e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 0.8s to complete
#     error(train)=6.36e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 0.8s to complete
#     error(train)=6.32e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 0.8s to complete
#     error(train)=6.15e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 0.8s to complete
#     error(train)=5.99e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 0.8s to complete
#     error(train)=6.00e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 0.8s to complete
#     error(train)=5.70e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 0.8s to complete
#     error(train)=5.60e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 0.8s to complete
#     error(train)=5.51e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 0.8s to complete
#     error(train)=5.44e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 0.8s to complete
#     error(train)=5.27e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 0.8s to complete
#     error(train)=5.20e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 0.8s to complete
#     error(train)=5.13e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 0.8s to complete
#     error(train)=5.02e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 0.8s to complete
#     error(train)=5.00e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 0.8s to complete
#     error(train)=4.87e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 0.8s to complete
#     error(train)=4.77e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 0.8s to complete
#     error(train)=4.73e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 0.8s to complete
#     error(train)=4.66e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 0.8s to complete
#     error(train)=4.54e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 0.8s to complete
#     error(train)=4.53e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 0.8s to complete
#     error(train)=4.45e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 0.8s to complete
#     error(train)=4.36e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 0.8s to complete
#     error(train)=4.27e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 0.8s to complete
#     error(train)=4.21e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 0.8s to complete
#     error(train)=4.16e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 0.8s to complete
#     error(train)=2.50e-01, acc(train)=9.27e-01, error(valid)=2.37e-01, acc(valid)=9.32e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 0.8s to complete
#     error(train)=1.73e-01, acc(train)=9.50e-01, error(valid)=1.71e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 0.8s to complete
#     error(train)=1.35e-01, acc(train)=9.61e-01, error(valid)=1.42e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 0.8s to complete
#     error(train)=1.15e-01, acc(train)=9.67e-01, error(valid)=1.30e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 0.8s to complete
#     error(train)=9.74e-02, acc(train)=9.71e-01, error(valid)=1.18e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 0.8s to complete
#     error(train)=8.06e-02, acc(train)=9.77e-01, error(valid)=1.06e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 0.8s to complete
#     error(train)=6.88e-02, acc(train)=9.80e-01, error(valid)=9.93e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 0.8s to complete
#     error(train)=7.03e-02, acc(train)=9.79e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 0.8s to complete
#     error(train)=5.41e-02, acc(train)=9.85e-01, error(valid)=9.10e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 0.8s to complete
#     error(train)=5.04e-02, acc(train)=9.86e-01, error(valid)=9.09e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 0.8s to complete
#     error(train)=4.30e-02, acc(train)=9.88e-01, error(valid)=8.93e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 0.8s to complete
#     error(train)=3.77e-02, acc(train)=9.89e-01, error(valid)=8.23e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 0.8s to complete
#     error(train)=3.30e-02, acc(train)=9.91e-01, error(valid)=8.59e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 0.8s to complete
#     error(train)=3.10e-02, acc(train)=9.92e-01, error(valid)=8.35e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 0.8s to complete
#     error(train)=3.38e-02, acc(train)=9.90e-01, error(valid)=9.25e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 16: 0.8s to complete
#     error(train)=2.34e-02, acc(train)=9.94e-01, error(valid)=7.87e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 17: 0.8s to complete
#     error(train)=1.98e-02, acc(train)=9.96e-01, error(valid)=7.77e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 18: 0.8s to complete
#     error(train)=2.15e-02, acc(train)=9.94e-01, error(valid)=8.89e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 19: 0.8s to complete
#     error(train)=1.51e-02, acc(train)=9.97e-01, error(valid)=8.09e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 20: 0.8s to complete
#     error(train)=1.29e-02, acc(train)=9.98e-01, error(valid)=7.93e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 21: 0.8s to complete
#     error(train)=2.05e-02, acc(train)=9.94e-01, error(valid)=9.44e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 22: 0.8s to complete
#     error(train)=1.12e-02, acc(train)=9.98e-01, error(valid)=8.26e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 23: 0.8s to complete
#     error(train)=1.04e-02, acc(train)=9.98e-01, error(valid)=8.64e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 24: 0.8s to complete
#     error(train)=1.01e-02, acc(train)=9.98e-01, error(valid)=8.60e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 25: 0.8s to complete
#     error(train)=8.33e-03, acc(train)=9.99e-01, error(valid)=9.07e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 26: 0.8s to complete
#     error(train)=9.18e-03, acc(train)=9.99e-01, error(valid)=8.71e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 27: 0.8s to complete
#     error(train)=5.83e-03, acc(train)=1.00e+00, error(valid)=8.63e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 28: 0.8s to complete
#     error(train)=5.19e-03, acc(train)=1.00e+00, error(valid)=8.72e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 0.9s to complete
#     error(train)=5.73e-03, acc(train)=1.00e+00, error(valid)=9.11e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 0.8s to complete
#     error(train)=5.57e-03, acc(train)=9.99e-01, error(valid)=8.96e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 0.8s to complete
#     error(train)=4.03e-03, acc(train)=1.00e+00, error(valid)=8.99e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 0.8s to complete
#     error(train)=3.61e-03, acc(train)=1.00e+00, error(valid)=9.07e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 0.8s to complete
#     error(train)=3.82e-03, acc(train)=1.00e+00, error(valid)=9.19e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 0.8s to complete
#     error(train)=5.09e-03, acc(train)=9.99e-01, error(valid)=9.43e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 0.8s to complete
#     error(train)=3.27e-03, acc(train)=1.00e+00, error(valid)=9.22e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 0.8s to complete
#     error(train)=2.79e-03, acc(train)=1.00e+00, error(valid)=9.21e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 0.8s to complete
#     error(train)=2.51e-03, acc(train)=1.00e+00, error(valid)=9.29e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 0.8s to complete
#     error(train)=2.67e-03, acc(train)=1.00e+00, error(valid)=9.33e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 0.8s to complete
#     error(train)=2.16e-03, acc(train)=1.00e+00, error(valid)=9.43e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 0.8s to complete
#     error(train)=2.06e-03, acc(train)=1.00e+00, error(valid)=9.52e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 0.8s to complete
#     error(train)=1.96e-03, acc(train)=1.00e+00, error(valid)=9.51e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 0.8s to complete
#     error(train)=1.90e-03, acc(train)=1.00e+00, error(valid)=9.63e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 0.8s to complete
#     error(train)=1.77e-03, acc(train)=1.00e+00, error(valid)=9.71e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 0.8s to complete
#     error(train)=1.66e-03, acc(train)=1.00e+00, error(valid)=9.70e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 0.8s to complete
#     error(train)=1.58e-03, acc(train)=1.00e+00, error(valid)=9.71e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 0.8s to complete
#     error(train)=1.56e-03, acc(train)=1.00e+00, error(valid)=9.98e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 0.8s to complete
#     error(train)=1.46e-03, acc(train)=1.00e+00, error(valid)=9.91e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 0.8s to complete
#     error(train)=1.38e-03, acc(train)=1.00e+00, error(valid)=9.97e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 0.8s to complete
#     error(train)=1.32e-03, acc(train)=1.00e+00, error(valid)=9.92e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 0.8s to complete
#     error(train)=1.31e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 0.8s to complete
#     error(train)=1.28e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 0.8s to complete
#     error(train)=1.17e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 0.8s to complete
#     error(train)=1.15e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 0.8s to complete
#     error(train)=1.08e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 0.8s to complete
#     error(train)=1.07e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 0.8s to complete
#     error(train)=1.04e-03, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 0.8s to complete
#     error(train)=9.83e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 0.8s to complete
#     error(train)=9.71e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 0.8s to complete
#     error(train)=9.49e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 0.8s to complete
#     error(train)=8.94e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 0.8s to complete
#     error(train)=8.93e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 0.8s to complete
#     error(train)=8.51e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 0.8s to complete
#     error(train)=8.31e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 0.8s to complete
#     error(train)=8.16e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 0.8s to complete
#     error(train)=7.87e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 0.8s to complete
#     error(train)=7.74e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 0.8s to complete
#     error(train)=7.78e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 0.8s to complete
#     error(train)=7.39e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 0.8s to complete
#     error(train)=7.05e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 0.8s to complete
#     error(train)=6.94e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 0.8s to complete
#     error(train)=6.75e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 0.8s to complete
#     error(train)=6.66e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 0.8s to complete
#     error(train)=6.45e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 0.8s to complete
#     error(train)=6.33e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 0.8s to complete
#     error(train)=6.26e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 0.8s to complete
#     error(train)=6.04e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 0.8s to complete
#     error(train)=5.97e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 0.8s to complete
#     error(train)=5.84e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 0.8s to complete
#     error(train)=5.73e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 0.8s to complete
#     error(train)=5.54e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 0.8s to complete
#     error(train)=5.50e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 0.8s to complete
#     error(train)=5.34e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 0.8s to complete
#     error(train)=5.30e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 0.8s to complete
#     error(train)=5.16e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 0.8s to complete
#     error(train)=5.08e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 0.8s to complete
#     error(train)=4.95e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 0.8s to complete
#     error(train)=4.89e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 0.8s to complete
#     error(train)=4.88e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 0.8s to complete
#     error(train)=4.69e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 0.8s to complete
#     error(train)=4.67e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 0.8s to complete
#     error(train)=4.55e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 0.8s to complete
#     error(train)=4.44e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 0.8s to complete
#     error(train)=4.39e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 0.8s to complete
#     error(train)=4.31e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 0.8s to complete
#     error(train)=4.29e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 0.8s to complete
#     error(train)=4.18e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 0.8s to complete
#     error(train)=4.15e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 0.8s to complete
#     error(train)=4.07e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 0.8s to complete
#     error(train)=4.00e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 0.8s to complete
#     error(train)=3.95e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 1: 0.8s to complete
#     error(train)=2.04e-01, acc(train)=9.39e-01, error(valid)=2.00e-01, acc(valid)=9.42e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 2: 0.8s to complete
#     error(train)=1.45e-01, acc(train)=9.57e-01, error(valid)=1.53e-01, acc(valid)=9.55e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 3: 0.8s to complete
#     error(train)=1.11e-01, acc(train)=9.68e-01, error(valid)=1.29e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 4: 0.8s to complete
#     error(train)=9.04e-02, acc(train)=9.74e-01, error(valid)=1.15e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 5: 0.8s to complete
#     error(train)=7.92e-02, acc(train)=9.77e-01, error(valid)=1.12e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 6: 0.8s to complete
#     error(train)=7.03e-02, acc(train)=9.80e-01, error(valid)=1.04e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 7: 0.8s to complete
#     error(train)=5.81e-02, acc(train)=9.83e-01, error(valid)=9.89e-02, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 8: 0.8s to complete
#     error(train)=5.12e-02, acc(train)=9.86e-01, error(valid)=9.53e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 9: 0.8s to complete
#     error(train)=4.36e-02, acc(train)=9.88e-01, error(valid)=8.84e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 10: 0.8s to complete
#     error(train)=4.30e-02, acc(train)=9.88e-01, error(valid)=9.21e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 11: 0.8s to complete
#     error(train)=3.70e-02, acc(train)=9.90e-01, error(valid)=9.81e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 12: 0.8s to complete
#     error(train)=3.03e-02, acc(train)=9.93e-01, error(valid)=8.98e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 13: 0.9s to complete
#     error(train)=2.85e-02, acc(train)=9.93e-01, error(valid)=9.21e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 14: 0.8s to complete
#     error(train)=2.37e-02, acc(train)=9.95e-01, error(valid)=9.13e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 15: 0.8s to complete
#     error(train)=2.07e-02, acc(train)=9.95e-01, error(valid)=9.10e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# ...
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 29: 0.8s to complete
#     error(train)=1.77e-02, acc(train)=9.96e-01, error(valid)=9.55e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 30: 0.8s to complete
#     error(train)=1.89e-02, acc(train)=9.95e-01, error(valid)=9.70e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 31: 0.8s to complete
#     error(train)=1.89e-02, acc(train)=9.95e-01, error(valid)=1.05e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 32: 0.8s to complete
#     error(train)=1.69e-02, acc(train)=9.96e-01, error(valid)=1.05e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 33: 0.8s to complete
#     error(train)=1.52e-02, acc(train)=9.97e-01, error(valid)=9.92e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 34: 0.8s to complete
#     error(train)=1.20e-02, acc(train)=9.98e-01, error(valid)=1.01e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 35: 0.8s to complete
#     error(train)=1.20e-02, acc(train)=9.98e-01, error(valid)=1.03e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 36: 0.8s to complete
#     error(train)=1.07e-02, acc(train)=9.98e-01, error(valid)=1.04e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 37: 0.8s to complete
#     error(train)=1.00e-02, acc(train)=9.98e-01, error(valid)=1.03e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 38: 0.8s to complete
#     error(train)=1.05e-02, acc(train)=9.98e-01, error(valid)=1.05e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 39: 0.8s to complete
#     error(train)=8.70e-03, acc(train)=9.99e-01, error(valid)=1.05e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 40: 0.8s to complete
#     error(train)=8.30e-03, acc(train)=9.99e-01, error(valid)=1.10e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 41: 0.8s to complete
#     error(train)=6.59e-03, acc(train)=9.99e-01, error(valid)=1.06e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 42: 0.8s to complete
#     error(train)=6.47e-03, acc(train)=9.99e-01, error(valid)=1.06e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 43: 0.8s to complete
#     error(train)=5.82e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 44: 0.8s to complete
#     error(train)=6.53e-03, acc(train)=9.99e-01, error(valid)=1.11e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 45: 0.8s to complete
#     error(train)=6.57e-03, acc(train)=9.99e-01, error(valid)=1.14e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 46: 0.8s to complete
#     error(train)=4.64e-03, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 47: 0.8s to complete
#     error(train)=5.53e-03, acc(train)=9.99e-01, error(valid)=1.14e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 48: 0.8s to complete
#     error(train)=4.02e-03, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 49: 0.9s to complete
#     error(train)=4.42e-03, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 50: 0.8s to complete
#     error(train)=3.13e-03, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 51: 0.8s to complete
#     error(train)=3.41e-03, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 52: 0.8s to complete
#     error(train)=2.90e-03, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 53: 0.8s to complete
#     error(train)=2.76e-03, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 54: 0.8s to complete
#     error(train)=2.68e-03, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 55: 0.8s to complete
#     error(train)=2.50e-03, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 56: 0.8s to complete
#     error(train)=2.51e-03, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 57: 0.8s to complete
#     error(train)=2.28e-03, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 58: 0.8s to complete
#     error(train)=2.17e-03, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 59: 0.9s to complete
#     error(train)=3.46e-03, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 60: 0.8s to complete
#     error(train)=1.94e-03, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 61: 0.8s to complete
#     error(train)=1.86e-03, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 62: 0.8s to complete
#     error(train)=1.91e-03, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 63: 0.8s to complete
#     error(train)=1.73e-03, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 64: 0.8s to complete
#     error(train)=1.66e-03, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 65: 0.8s to complete
#     error(train)=1.60e-03, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 66: 0.8s to complete
#     error(train)=1.56e-03, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 67: 0.8s to complete
#     error(train)=1.75e-03, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 68: 0.8s to complete
#     error(train)=1.42e-03, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 69: 0.8s to complete
#     error(train)=1.36e-03, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 70: 0.8s to complete
#     error(train)=1.37e-03, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 71: 0.8s to complete
#     error(train)=1.29e-03, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 72: 0.8s to complete
#     error(train)=1.28e-03, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 73: 0.8s to complete
#     error(train)=1.22e-03, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 74: 0.8s to complete
#     error(train)=1.20e-03, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 75: 0.8s to complete
#     error(train)=1.18e-03, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 76: 0.8s to complete
#     error(train)=1.12e-03, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 77: 0.8s to complete
#     error(train)=1.11e-03, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 78: 0.8s to complete
#     error(train)=1.06e-03, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 79: 0.8s to complete
#     error(train)=1.03e-03, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 80: 0.8s to complete
#     error(train)=1.02e-03, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 81: 0.8s to complete
#     error(train)=1.07e-03, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 82: 0.8s to complete
#     error(train)=9.64e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 83: 0.8s to complete
#     error(train)=9.47e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 84: 0.8s to complete
#     error(train)=9.15e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 85: 0.8s to complete
#     error(train)=8.96e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 86: 0.8s to complete
#     error(train)=8.70e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 87: 0.8s to complete
#     error(train)=8.63e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 88: 0.8s to complete
#     error(train)=8.40e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 89: 0.8s to complete
#     error(train)=8.24e-04, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 90: 0.8s to complete
#     error(train)=8.31e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 91: 0.8s to complete
#     error(train)=7.98e-04, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 92: 0.8s to complete
#     error(train)=7.90e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 93: 0.8s to complete
#     error(train)=7.60e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 94: 0.8s to complete
#     error(train)=7.44e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 95: 0.8s to complete
#     error(train)=7.32e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 96: 0.8s to complete
#     error(train)=7.17e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 97: 0.8s to complete
#     error(train)=7.13e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 98: 0.8s to complete
#     error(train)=7.13e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 99: 0.8s to complete
#     error(train)=6.92e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Epoch 100: 0.8s to complete
#     error(train)=6.70e-04, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
